# %%
import xlrd
from xlrd import *
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=xlrd.open_workbook("C:/Users/user/OneDrive/Work/UB_Master/s_ws_2016_2017/Michael_Hofmann_2017_2nd_lab/data.xlsx")

# List sheet names, and pull a sheet by name
#
sheet_names = data.sheet_names()
print('Sheet Names', sheet_names)
# Out:
# Sheet Names ['sheet1', 'changing', 'data']

# %%
table_sheet = data.sheet_by_name(sheet_names[2])
# Or grab the first sheet by index 
    #xl_sheet = xl_workbook.sheet_by_index(0)
# sheet1= excel_sheet.sheet_by_name('parents')

# for i in range(0,table_sheet.nrows):        
#     row= table_sheet.row_slice(i)        
#     NG = row[0].value        
#     NPT = row[1].value        
#     CM = row[2].value
#     IL = row[3].value
# r = sheet.row(0) #returns all the CELLS of row 0,
# c = sheet.col_values(0) #returns all the VALUES of column 0,
NG=table_sheet.row_values(0)
NPT=table_sheet.row_values(1)
CM=table_sheet.row_values(2)
IL=table_sheet.row_values(3)
#now start to whisker box plotting
ratio = [NG, NPT, CM, IL]

# %%
#trying to figure out 1D plot?
xNG = np.arange(0,len(NG)) # this is the value where you want the data to appear on the y-axis.
xNPT = np.arange(0,len(NPT)) # this is the value where you want the data to appear on the y-axis.
xCM = np.arange(0,len(CM)) # this is the value where you want the data to appear on the y-axis.
xIL = np.arange(0,len(IL)) # this is the value where you want the data to appear on the y-axis.
# xNG.fill(0)
# xNPT = np.empty(len(NPT)) # this is the value where you want the data to appear on the y-axis.
# xNPT.fill(1)
# xCM = np.empty(len(CM)) # this is the value where you want the data to appear on the y-axis.
# xCM.fill(2)
# xIL = np.empty(len(IL)) # this is the value where you want the data to appear on the y-axis.
# xIL.fill(3)
# Create a figure instance
# plt.figure()
# plt.boxplot(ratio)
# plt.show()
plt.figure()
plt.scatter(xNG,NG,color='r')
plt.show()
plt.figure()
plt.scatter(xNPT,NPT,color='g')
plt.show()
plt.figure()
plt.scatter(xCM,CM,color='m')
plt.show()
plt.figure()
plt.scatter(xIL,IL,color='c')
plt.show()
