# %%
import xlrd
from xlrd import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import itertools
import seaborn as sns
# %matplotlib inline

# %%
data=xlrd.open_workbook("C:/Users/holme/OneDrive/Work/UB_Master/s_ws_2016_2017/Michael_Hofmann_2017_2nd_lab/data.xlsx")

# List sheet names, and pull a sheet by name
#
sheet_names = data.sheet_names()
print('Sheet Names', sheet_names)
# Out:
# Sheet Names ['sheet1', 'changing', 'Sheet3', 'data', 'original', 'Sheet4', 'Sheet5', 'Sheet2', 'snsdc_2', 'snsdc_log', 'snsdc', 'snsd', 'snsd_log']

# %%
table_sheet = data.sheet_by_name('data')
# Or grab the first sheet by index 
    #xl_sheet = xl_workbook.sheet_by_index(0)
# sheet1= excel_sheet.sheet_by_name('parents')

# for i in range(0,table_sheet.nrows):        
#     row= table_sheet.row_slice(i)        
#     NG = row[0].value        
#     NPT = row[1].value        
#     CM = row[2].value
#     IL = row[3].value
# r = sheet.row(0) #returns all the CELLS of row 0,
# c = sheet.col_values(0) #returns all the VALUES of column 0,
NG=table_sheet.row_values(0)
NPT=table_sheet.row_values(1)
CM=table_sheet.row_values(2)
IL=table_sheet.row_values(3)
#now start to whisker box plotting
# ratio = [NG, NPT, CM, IL]
#trying to figure out 1D plot?
name = np.arange(0,len(NG)) # this is the value where you want the data to appear on the y-axis.
#885 29345 3171956 93750 1880 2101630 147905 47157 
#49302 1221203 13120 37162 23207 143816 68326 19201 84618 3592123 3341804 77383 72347 104419
name_p=[[name[0]],[name[1]],name[2:29],name[29:37],name[37],name[38:46],name[46:55],name[55],name[56],name[57:61],name[61],name[62],name[63:66],name[66],name[67:69],name[69:72],name[72],name[73:88],name[88:91],name[91],name[92],name[93:100]]
####################
NG_p=[NG[0],NG[1],NG[2:29],NG[29:37],NG[37],NG[38:46],NG[46:55],NG[55],NG[56],NG[57:61],NG[61],NG[62],NG[63:66],NG[66],NG[67:69],NG[69:72],NG[72],NG[73:88],NG[88:91],NG[91],NG[92],NG[93:100]]
########################
NPT_p=[NPT[0],NPT[1],NPT[2:29],NPT[29:37],NPT[37],NPT[38:46],NPT[46:55],NPT[55],NPT[56],NPT[57:61],NPT[61],NPT[62],NPT[63:66],NPT[66],NPT[67:69],NPT[69:72],NPT[72],NPT[73:88],NPT[88:91],NPT[91],NPT[92],NPT[93:100]]
###########################
CM_p=[CM[0],CM[1],CM[2:29],CM[29:37],CM[37],CM[38:46],CM[46:55],CM[55],CM[56],CM[57:61],CM[61],CM[62],CM[63:66],CM[66],CM[67:69],CM[69:72],CM[72],CM[73:88],CM[88:91],CM[91],CM[92],CM[93:100]]
############################
IL_p=[IL[0],IL[1],IL[2:29],IL[29:37],IL[37],IL[38:46],IL[46:55],IL[55],IL[56],IL[57:61],IL[61],IL[62],IL[63:66],IL[66],IL[67:69],IL[69:72],IL[72],IL[73:88],IL[88:91],IL[91],IL[92],IL[93:100]]

print(len(name_p),len(NG_p),len(NPT_p),len(CM_p),len(IL_p))
# Out:
# 22 22 22 22 22

# %%
#categorized by region

new_style = {'grid': True}
sns.set_style("dark")
alone=plt.figure(figsize=(15,15))
#for colormap
# colors = iter(cm.prism(np.linspace(0, 0.6, len(name_p))))
colors1=itertools.cycle(['#9EC53A','#50BEA3','#38784C','#9B84F0','#C54F71','#783C75','#3399E1','#006078','#052F61','#DE9C3C','#E76F39','#C62324',])
colors2=itertools.cycle(['#9EC53A','#50BEA3','#38784C','#9B84F0','#C54F71','#783C75','#3399E1','#006078','#052F61','#DE9C3C','#E76F39','#C62324',])

x_ax1=[0,0]
x_ax2=[100,100]
y_ng=[0,0.15]
y_npt=[0,0.04]
y_cm=[0,0.08]
y_il=[0.82,0.98]

#NG===================================
labels1=['Holocentriformes','Kurtiformes','Gobiiformes','IncertaeSedis','Mugiliformes','Cichliformes','Blenniiformes','Gobiesociformes','Atheriniformes','Cyprinodontiformes','Synbranchiformes','Carangiformes','Anabantiformes','Pleuronectiformes','Syngnathiformes','Callionymiformes','Labriformes','Perciformes','Scorpaeniformes','Acanthuriformes','Lophiiformes','Tetraodontiformes']
ng_labels=[]
ng=alone.add_subplot(2,2,1)
npt_labels=[]
npt=alone.add_subplot(2,2,2)
cm_labels=[]
cm=alone.add_subplot(2,2,3)
il_labels=[]
il=alone.add_subplot(2,2,4)
plt.subplots_adjust(wspace=0.5, hspace=0.3)
for i in range(0,len(name_p)):
    ng.scatter(name_p[i],NG_p[i],s=30,marker='o',color=next(colors1))
    ng=alone.add_subplot(2,2,1)
    ng_labels.append(labels1[i])


plt.gca().set_prop_cycle(None)
plt.ylim([0,0.15])
plt.xlim([-10,110])
plt.title('NG', fontsize=30)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(ng_labels,bbox_to_anchor=(1.35, 1.02),loc='upper right')
ng.plot(x_ax1,y_ng,'k--',x_ax2,y_ng,'k--')
plt.grid()
# #NPT==================================
plt.gca().set_prop_cycle(None)
for i in range(0,len(name_p)):
    npt.scatter(name_p[i],NPT_p[i],s=30,marker='o',color=next(colors2))
    npt=alone.add_subplot(2,2,2)
    npt_labels.append(labels1[i])

plt.ylim([0,0.04])
plt.xlim([-10,110])
plt.legend(npt_labels,bbox_to_anchor=(1.35, 1.02),loc='upper right')
plt.title('NPT', fontsize=30)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
npt.plot(x_ax1,y_npt,'k--',x_ax2,y_npt,'k--')
plt.grid()
#CM===================================
for i in range(0,len(name_p)):
    cm.scatter(name_p[i],CM_p[i],s=30,marker='o',color=next(colors1))
    cm=alone.add_subplot(2,2,3)
    cm_labels.append(labels1[i])

plt.ylim([0,0.08])
plt.xlim([-10,110])
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title('CM', fontsize=30)
plt.legend(cm_labels,bbox_to_anchor=(1.35, 1.02),loc='upper right')
cm.plot(x_ax1,y_cm,'k--',x_ax2,y_cm,'k--')
plt.grid()
# #IL===================================
for i in range(0,len(name_p)):
    il.scatter(name_p[i],IL_p[i],s=30,marker='o',color=next(colors2))
    il=alone.add_subplot(2,2,4)
    il_labels.append(labels1[i])

plt.ylim([0.82,0.98])
plt.xlim([-10,110])
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title('IL', fontsize=30)
plt.legend(il_labels,bbox_to_anchor=(1.35, 1.02),loc='upper right')
il.plot(x_ax1,y_il,'k--',x_ax2,y_il,'k--')
plt.grid()
plt.show()

# %%
# #altogether//////////////////////////////
# new_style = {'grid': True}
# sns.set_style("darkgrid")
# allt=plt.figure(figsize=(15,5))
# all_1l=['NG','NPT','CM','IL']
# all_2l=['NG','NPT','CM']
# all_1=allt.add_subplot(1,2,1)
# plt.subplots_adjust(wspace=0.3)

# all_1.scatter(name,NG,c='#9EC53A',marker='o',edgecolor='none',s=20)
# all_1.scatter(name,NPT,c='#006078',marker='o',edgecolor='none',s=20)
# all_1.scatter(name,CM,c='#E34A3C',marker='o',edgecolor='none',s=20)
# all_1.scatter(name,IL,c='#FFBC4F',marker='o',edgecolor='none',s=20)
# plt.legend(all_1l,bbox_to_anchor=(1.25, 1.02),loc='upper right')
# plt.ylim([0,1.0])
# plt.xlim([-10,110])
# all_1.plot(x_ax1,[0,1],'k--',x_ax2,[0,1],'k--')

# all_2=allt.add_subplot(1,2,2)
# plt.subplots_adjust(wspace=0.4)
# all_2.scatter(name,NG,c='#9EC53A',marker='o',edgecolor='none',s=20)
# all_2.scatter(name,NPT,c='#006078',marker='o',edgecolor='none',s=20)
# all_2.scatter(name,CM,c='#E34A3C',marker='o',edgecolor='none',s=20)
# plt.legend(all_2l,bbox_to_anchor=(1.25, 1.02),loc='upper right')
# plt.ylim([0,0.15])
# plt.xlim([-10,110])
# all_2.plot(x_ax1,y_ng,'k--',x_ax2,y_ng,'k--')
# plt.show()

#boxplot?//////////////////////////////
# dfb_1=pd.DataFrame({"NG":NG, "NPT":NPT, "CM":CM,"IL":IL})
# dfb_1= dfb_1[["NG", "NPT", "CM","IL"]]
# dfb_2=pd.DataFrame({"NG":NG, "NPT":NPT, "CM":CM})
# dfb_2= dfb_2[["NG", "NPT", "CM"]]
# boxes=plt.figure(figsize=(15,15))
# boxes1=boxes.add_subplot(2,2,1)
# boxes2=boxes.add_subplot(2,2,2)
# boxes3=boxes.add_subplot(2,2,3)
# boxes4=boxes.add_subplot(2,2,4)
# dfb_1.plot.box(ax=boxes1,sym='r+',title="Subregion comparison")
# dfb_2p=dfb_2.plot.box(ax=boxes2,sym='r+',title="Subregion comparison|NG, NPT, CM")
# dfb_2p.set_ylim([0,0.1])
# sns.boxplot(data=dfb_1,ax=boxes3, order=["NG", "NPT","CM","IL"])
# sns.stripplot(data=dfb_1,size=3.5, jitter=True, edgecolor="k",linewidth=0.3,ax=boxes3)
# sns.boxplot(data=dfb_2,ax=boxes4)
# sns.stripplot(data=dfb_2,size=3.5, jitter=True, edgecolor="k",linewidth=0.3,ax=boxes4)

# plt.show()

# %%
#try to use seaborn and pands for strip plot
boxes=plt.figure(figsize=(25,30))
plt.subplots_adjust(wspace=0.5, hspace=0.3)
boxes1=boxes.add_subplot(2,2,1)
boxes2=boxes.add_subplot(2,2,2)
boxes3=boxes.add_subplot(2,2,3)
boxes4=boxes.add_subplot(2,2,4)
dfe = pd.ExcelFile("C:/Users/holme/OneDrive/Work/UB_Master/s_ws_2016_2017/Michael_Hofmann_2017_2nd_lab/data.xlsx")
dfs= dfe.parse('snsd')
sns.set_style('darkgrid')
sns.set_context(context='poster',font_scale=1.2)#rc={'font.size':60.0,'axes.titlesize':60.0,'axes.labelsize':40.0})
ngs=sns.stripplot(x='NG',y='Family',data=dfs,size=10,jitter=True, edgecolor="k",linewidth=0.5,ax=boxes1)
npts=sns.stripplot(x='NPT',y='Family',data=dfs,size=10,jitter=True, edgecolor="k",linewidth=0.5,ax=boxes4)
cms=sns.stripplot(x='CM',y='Family',data=dfs,size=10,jitter=True, edgecolor="k",linewidth=0.5,ax=boxes3)
ils=sns.stripplot(x='IL',y='Family',data=dfs,size=10,jitter=True, edgecolor="k",linewidth=0.5,ax=boxes2)
# npts.set(ylabel='',yticks=([]))
ngs.set_xlabel('NG/Hypothalamus',fontsize=40,labelpad=30)
ngs.set_ylabel('Family',fontsize=40,labelpad=30)
npts.set_xlabel('NPT/Hypothalamus',fontsize=40,labelpad=30)
npts.set_ylabel('Family',fontsize=40,labelpad=30)
cms.set_xlabel('CM/Hypothalamus',fontsize=40,labelpad=30)
cms.set_ylabel('Family',fontsize=40,labelpad=30)
ils.set_xlabel('IL/Hypothalamus',fontsize=40,labelpad=30)
ils.set_ylabel('Family',fontsize=40,labelpad=30)
plt.show()

# %%
#boxplot?
boxesa=plt.figure(figsize=(25,30))
plt.subplots_adjust(wspace=0.5, hspace=0.3)
boxesa1=boxesa.add_subplot(2,2,1)
boxesa2=boxesa.add_subplot(2,2,2)
boxesa3=boxesa.add_subplot(2,2,3)
boxesa4=boxesa.add_subplot(2,2,4)
#log_axis
boxesa1.set_yscale('log')
# ,size=10,jitter=True, edgecolor="k",linewidth=0.5
dfc=dfe.parse('snsdc')
sns.stripplot(x='Ratio',y='NG',size=10,jitter=True, edgecolor="k",linewidth=0.5,data=dfc,ax=boxesa1)
sns.boxplot(x='Ratio',y='NG',data=dfc,ax=boxesa1)
sns.stripplot(x='Ratio',y='NPT',size=10,jitter=True, edgecolor="k",linewidth=0.5,data=dfc,ax=boxesa2)
sns.boxplot(x='Ratio',y='NPT',data=dfc,ax=boxesa2)
sns.stripplot(x='Ratio',y='CM',size=10,jitter=True, edgecolor="k",linewidth=0.5,data=dfc,ax=boxesa3)
sns.boxplot(x='Ratio',y='CM',data=dfc,ax=boxesa3)
sns.stripplot(x='Ratio',y='IL',size=10,jitter=True, edgecolor="k",linewidth=0.5,data=dfc,ax=boxesa4)
sns.boxplot(x='Ratio',y='IL',data=dfc,ax=boxesa4)
plt.show()

# %%
#boxplot2_log
comparison=plt.figure(figsize=(30,15))
# size=10,jitter=True, edgecolor="k",linewidth=0.5
dfc_2=dfe.parse('snsdc_2')
logbox=sns.stripplot(x='Region',y='log(Ratio of the Region)',hue='Reference',size=10,jitter=True, edgecolor="k",linewidth=0.5,data=dfc_2,split=True)
sns.boxplot(x='Region',y='log(Ratio of the Region)',hue='Reference',data=dfc_2)
logbox.tick_params(labelsize=25)
logbox.set_xlabel('Brain Region',fontsize=35,labelpad=30)
logbox.set_ylabel('log(Ratio of the Region)',fontsize=35,labelpad=30)
plt.legend(prop={'size':25})
plt.tight_layout()
plt.show()
comparison.savefig("comparison.svg",format='svg', dpi=1200)

# %%
#brain_ratio
boxesb=plt.figure(figsize=(25,30))
plt.subplots_adjust(wspace=0.5, hspace=0.3)
boxesb1=boxesb.add_subplot(2,2,1)
boxesb2=boxesb.add_subplot(2,2,2)
boxesb3=boxesb.add_subplot(2,2,3)
boxesb4=boxesb.add_subplot(2,2,4)
dfs= dfe.parse('snsd')
sns.set_style('darkgrid')
sns.set_context(context='poster',font_scale=1.2)#rc={'font.size':60.0,'axes.titlesize':60.0,'axes.labelsize':40.0})
ngs=sns.stripplot(x='NGb',y='Family',data=dfs,size=10,jitter=True, edgecolor="k",linewidth=0.5,ax=boxesb1)
npts=sns.stripplot(x='NPTb',y='Family',data=dfs,size=10,jitter=True, edgecolor="k",linewidth=0.5,ax=boxesb4)
cms=sns.stripplot(x='CMb',y='Family',data=dfs,size=10,jitter=True, edgecolor="k",linewidth=0.5,ax=boxesb3)
ils=sns.stripplot(x='ILb',y='Family',data=dfs,size=10,jitter=True, edgecolor="k",linewidth=0.5,ax=boxesb2)
# npts.set(ylabel='',yticks=([]))
ngs.set_xlabel('NG/Whole Brain',fontsize=40,labelpad=30)
ngs.set_ylabel('Order',fontsize=40,labelpad=30)
npts.set_xlabel('NPT/Whole Brain',fontsize=40,labelpad=30)
npts.set_ylabel('Order',fontsize=40,labelpad=30)
cms.set_xlabel('CM/Whole Brain',fontsize=40,labelpad=30)
cms.set_ylabel('Order',fontsize=40,labelpad=30)
ils.set_xlabel('IL/Whole Brain',fontsize=40,labelpad=30)
ils.set_ylabel('Order',fontsize=40,labelpad=30)
plt.show()

# %%
#brain_ratio_log
boxeslog=plt.figure(figsize=(25,30))
plt.subplots_adjust(wspace=0.5, hspace=0.3)
boxeslog1=boxeslog.add_subplot(2,2,1)
boxeslog2=boxeslog.add_subplot(2,2,2)
boxeslog3=boxeslog.add_subplot(2,2,3)
boxeslog4=boxeslog.add_subplot(2,2,4)

dflog= dfe.parse('snsd_log')
sns.set_style('darkgrid')
sns.set_context(context='poster',font_scale=1.2)#rc={'font.size':60.0,'axes.titlesize':60.0,'axes.labelsize':40.0})
nglog=sns.stripplot(x='NG',y='Family',data=dflog,size=10,jitter=True, edgecolor="k",linewidth=0.5,ax=boxeslog1)
nptlog=sns.stripplot(x='NPT',y='Family',data=dflog,size=10,jitter=True, edgecolor="k",linewidth=0.5,ax=boxeslog4)
cmlog=sns.stripplot(x='CM',y='Family',data=dflog,size=10,jitter=True, edgecolor="k",linewidth=0.5,ax=boxeslog3)
illog=sns.stripplot(x='IL',y='Family',data=dflog,size=10,jitter=True, edgecolor="k",linewidth=0.5,ax=boxeslog2)
# npts.set(ylabel='',yticks=([]))
nglog.set_xlabel('log(NG/Functional region)',fontsize=40,labelpad=30)
nglog.set_ylabel('Order',fontsize=40,labelpad=30)
nglog.set(xlim=(-3,1))
nptlog.set_xlabel('log(NPT/Functional region)',fontsize=40,labelpad=30)
nptlog.set_ylabel('Order',fontsize=40,labelpad=30)
nptlog.set(xlim=(-3,1))
cmlog.set_xlabel('log(CM/Functional region)',fontsize=40,labelpad=30)
cmlog.set_ylabel('Order',fontsize=40,labelpad=30)
cmlog.set(xlim=(-3,1))
illog.set_xlabel('log(IL/Functional region)',fontsize=40,labelpad=30)
illog.set_ylabel('Order',fontsize=40,labelpad=30)
illog.set(xlim=(-3,1))
plt.show()

# %%
#brain_ratio_log_total_brain
boxeslogt=plt.figure(figsize=(25,30))
plt.subplots_adjust(wspace=0.5, hspace=0.3)
boxeslogt1=boxeslogt.add_subplot(2,2,1)
boxeslogt2=boxeslogt.add_subplot(2,2,2)
boxeslogt3=boxeslogt.add_subplot(2,2,3)
boxeslogt4=boxeslogt.add_subplot(2,2,4)

dflog= dfe.parse('snsd_log')
sns.set_style('darkgrid')
sns.set_context(context='poster',font_scale=1.2)#rc={'font.size':60.0,'axes.titlesize':60.0,'axes.labelsize':40.0})
nglogt=sns.stripplot(x='NGb',y='Family',data=dflog,size=10,jitter=True, edgecolor="k",linewidth=0.5,ax=boxeslogt1)
nptlogt=sns.stripplot(x='NPTb',y='Family',data=dflog,size=10,jitter=True, edgecolor="k",linewidth=0.5,ax=boxeslogt4)
cmlogt=sns.stripplot(x='CMb',y='Family',data=dflog,size=10,jitter=True, edgecolor="k",linewidth=0.5,ax=boxeslogt3)
illogt=sns.stripplot(x='ILb',y='Family',data=dflog,size=10,jitter=True, edgecolor="k",linewidth=0.5,ax=boxeslogt2)
# npts.set(ylabel='',yticks=([]))
nglogt.set_xlabel('log(NG/Whole Brain)',fontsize=40,labelpad=30)
nglogt.set_ylabel('Order',fontsize=40,labelpad=30)
nglogt.set(xlim=(-3.5,1.5))
nptlogt.set_xlabel('log(NPT/Whole Brain)',fontsize=40,labelpad=30)
nptlogt.set_ylabel('Order',fontsize=40,labelpad=30)
nptlogt.set(xlim=(-3.5,1.5))
cmlogt.set_xlabel('log(CM/Whole Brain)',fontsize=40,labelpad=30)
cmlogt.set_ylabel('Order',fontsize=40,labelpad=30)
cmlogt.set(xlim=(-3.5,1.5))
illogt.set_xlabel('log(IL/Whole Brain)',fontsize=40,labelpad=30)
illogt.set_ylabel('Order',fontsize=40,labelpad=30)
illogt.set(xlim=(-3.5,1.5))
plt.show()

# try to save separate figures? 
boxeslogt.savefig('boxeslogt1_figure.png',bbox_inches='tight')

# %%
#brain_ratio_log_for_saving
frng=plt.figure(figsize=(10,13))
# plt.subplots_adjust(wspace=0.5, hspace=0.3)
# boxeslogt1=boxeslogt.add_subplot(4,1,1)
# boxeslogt2=boxeslogt.add_subplot(4,1,2)
# boxeslogt3=boxeslogt.add_subplot(4,1,3)
# boxeslogt4=boxeslogt.add_subplot(4,1,4)

dflog= dfe.parse('snsd_log')
sns.set_style('darkgrid')
sns.set_context(context='poster',font_scale=1.2)#rc={'font.size':60.0,'axes.titlesize':60.0,'axes.labelsize':40.0})
nglogt=sns.stripplot(x='NG',y='Family',data=dflog,size=10,jitter=True, edgecolor="k",linewidth=0.5)
nglogt.set_xlabel('log(NG/Funtional Region)',fontsize=40,labelpad=30)
nglogt.set_ylabel('Family',fontsize=40,labelpad=30)
nglogt.set(xlim=(-3.5,1.5))
plt.show()
plt.tight_layout()
frng.savefig("frNG.svg",format='svg')
frnpt=plt.figure(figsize=(10,13))
nptlogt=sns.stripplot(x='NPT',y='Family',data=dflog,size=10,jitter=True, edgecolor="k",linewidth=0.5)
nptlogt.set_xlabel('log(NPT/Funtional Region)',fontsize=40,labelpad=30)
nptlogt.set_ylabel('Order',fontsize=40,labelpad=30)
nptlogt.set(xlim=(-3.5,1.5))
plt.show()
plt.tight_layout()
frnpt.savefig("frNPT.svg",format='svg')
frcm=plt.figure(figsize=(10,13))
cmlogt=sns.stripplot(x='CM',y='Family',data=dflog,size=10,jitter=True, edgecolor="k",linewidth=0.5)
cmlogt.set_xlabel('log(CM/Funtional Region)',fontsize=40,labelpad=30)
cmlogt.set_ylabel('Order',fontsize=40,labelpad=30)
cmlogt.set(xlim=(-3.5,1.5))
plt.show()
plt.tight_layout()
frcm.savefig("frCM.svg",format='svg')
fril=plt.figure(figsize=(10,13))
illogt=sns.stripplot(x='IL',y='Family',data=dflog,size=10,jitter=True, edgecolor="k",linewidth=0.5)
illogt.set_xlabel('log(IL/Funtional Region)',fontsize=40,labelpad=30)
illogt.set_ylabel('Order',fontsize=40,labelpad=30)
illogt.set(xlim=(-3.5,1.5))
# npts.set(ylabel='',yticks=([]))
plt.show()
plt.tight_layout()
fril.savefig("frIL.svg",format='svg')

# try to save separate figures? 
# boxeslogt.savefig('boxeslogt1_figure.png',bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-a01eeb3952c5> in <module>()
#      15 nglogt.set(xlim=(-3.5,1.5))
#      16 plt.show()
# ---> 17 plt.tight_layout()
#      18 frng.savefig("frNG.svg",format='svg')
#      19 frnpt=plt.figure(figsize=(10,13))
#
# C:\Users\holme\Anaconda3\lib\site-packages\matplotlib\pyplot.py in tight_layout(pad, h_pad, w_pad, rect)
#    1385
#    1386     fig = gcf()
# -> 1387     fig.tight_layout(pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    1388
#    1389
#
# C:\Users\holme\Anaconda3\lib\site-packages\matplotlib\figure.py in tight_layout(self, renderer, pad, h_pad, w_pad, rect)
#    1750                                          renderer,
#    1751                                          pad=pad, h_pad=h_pad, w_pad=w_pad,
# -> 1752                                          rect=rect)
#    1753
# ...
